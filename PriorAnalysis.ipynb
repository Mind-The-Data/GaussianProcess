# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
import seaborn as sns
import pymc3 as pm
# Out:
# /home/brian/anaconda2/envs/py36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# #### Gamma dist for eta and rho

# %%
# eta param
# I like 5, 10. 
plt.style.use('seaborn-darkgrid')
x = np.linspace(0, 3, 200)
alphas = [5, 4, 3, 6]
betas = [10, 8, 6, 12]
for a, b in zip(alphas, betas):
    pdf = st.gamma.pdf(x, a, scale=1.0/b)
    plt.plot(x, pdf, label=r'$\alpha$ = {}, $\beta$ = {}'.format(a, b))
plt.xlabel('x', fontsize=12)
plt.ylabel('f(x)', fontsize=12)
plt.legend(loc=1)
plt.show()

# %%
# lengthscale param ls
# 100-1000
# I like 2, .007
plt.style.use('seaborn-darkgrid')
x = np.linspace(0, 1000, 200)
alphas = [3, 2, 5, 6]
betas = [.01, .007, .01, .015]
for a, b in zip(alphas, betas):
    pdf = st.gamma.pdf(x, a, scale=1/b, loc=0)
    plt.plot(x, pdf, label=r'$\alpha$ = {}, $\beta$ = {}'.format(a, b))
plt.xlabel('x', fontsize=12)
plt.ylabel('f(x)', fontsize=12)
plt.legend(loc=1)
plt.show()

# %%
# lengthscale param lsq
plt.figure(figsize=(8,6))
plt.style.use('seaborn-darkgrid')
x = np.linspace(0, 800**2, 200)
alphas = [4, 3, 3.5, 10]
betas = [.00007, .00001, .000012, .00005]
for a, b in zip(alphas, betas):
    pdf = st.gamma.pdf(x, a, scale=1/b, loc=0)
    plt.plot(x, pdf, label=r'$\alpha$ = {}, $\beta$ = {}'.format(a, b))
plt.xlabel('x', fontsize=12)
plt.ylabel('f(x)', fontsize=12)
plt.legend(loc=1)
plt.show()

# %%
#ls = np.linspace(0,1000,100)
#plt.plot(ls, 1*np.exp(1e4/ls));

for esq,lsq in zip([1,1,1,.3],[1e4,4e4,1e5,5e5]):
    ls = round(np.sqrt(lsq))
    #es = round(np.sqrt(esq),1)
    x = np.linspace(0,1e3,50)
    plt.plot(x,esq*np.exp(-x**2/(lsq)), label=r'$l^2$ = {} , $3ls$ = {}, $\sigma^2$ = {}'\
             .format((lsq),(3*ls),(esq)))

plt.xlabel('distance (miles)')
plt.legend();
#plt.title(r'  $l$ = {}'.format(ls) + r',   $3l$ = {}'.format(3*ls));

# %%
# elevation 
etasq = .3
lsq = 6e4
ls = round(np.sqrt(lsq))
x = np.linspace(0,1e3,50)
for etasq,lsq in zip([1,1,1,.3],[1e4,5e4,1e5,5e5]):
    ls = round(np.sqrt(lsq))
    plt.plot(x,etasq*np.exp(-x**2/(lsq)), label =r'$l$ = {}'.format(ls) + r',   $3l$ = {}'.format(3*ls))
plt.xlabel('elevation (meters)')
plt.legend();
#plt.title(r'  $l$ = {}'.format(ls) + r',   $3l$ = {}'.format(3*ls));

# %%
plt.style.use('seaborn-darkgrid')
x = np.linspace(0, 5, 200)
for b in [0.7, 1.0, 2.0]:
    pdf = st.cauchy.pdf(x, scale=b)
    plt.plot(x, pdf, label=r'$\beta$ = {}'.format(b))
plt.xlabel('x', fontsize=12)
plt.ylabel('f(x)', fontsize=12)
plt.legend(loc=1)
plt.show()

# %%
x = np.linspace(0, 1000, 200)
for b in [150, 300, 200]:
    pdf = st.cauchy.pdf(x, scale=b)
    plt.plot(x, pdf, label=r'$\beta$ = {}'.format(b))
plt.xlabel('x', fontsize=12)
plt.ylabel('f(x)', fontsize=12)
plt.legend(loc=1)
plt.show()

# %%
# sigma ndvi
plt.figure(figsize=(8,6))
plt.style.use('seaborn-darkgrid')
x = np.linspace(0, 2, 200)
alphas = [3,4,5,6]
betas = [8,12,10,12]
for a, b in zip(alphas, betas):
    pdf = st.gamma.pdf(x, a, scale=1/b, loc=0)
    plt.plot(x, pdf, label=r'$\alpha$ = {}, $\beta$ = {}'.format(a, b))
plt.xlabel('x', fontsize=12)
plt.ylabel('f(x)', fontsize=12)
plt.legend(loc=1)
plt.show()
